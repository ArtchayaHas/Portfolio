# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#key
API_KEY = 'AIzaSyBViI9lKSAGL8yoKXl3D7cCWmfJ0iiWi8w'
CHANNEL_ID = 'UCTkyJbRhal4voLZxmdRSssQ'

# %%
#make API call
def get_vid_details(video_id):
    url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()
    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['favoriteCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    
    
    return view_count, like_count, comment_count

# %%
def get_vid(df):
    #make API call
    pageToken =''
    url = 'https://www.googleapis.com/youtube/v3/search?key='+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&publishedBefore=2022-09-20T00:00:00Z&maxResults=1000"+pageToken
    response = requests.get(url).json()
    time.sleep(1)
    
    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = str(video_title).replace("&amp;","")
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]
            
            view_count, like_count, comment_count = get_vid_details(video_id)
            
            df = df.append({'video_id' : video_id, 'video_title' : video_title,'upload_date' : upload_date, 
                            'view_count' : view_count, 'like_count' : like_count,
                           'comment_count': comment_count}, ignore_index = True)
    
    return df

# %%
#build dataframe
df = pd.DataFrame(columns = ['video_id', 'video_title', 'upload_date', 'view_count', 'like_count', 'comment_count'], dtype = object)

df = get_vid(df)

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   jVp8kWxCpn4  【試聴動画】TOKIMEKI Runners（12人Ver.) / 虹ヶ咲学園スクールアイド...
# 1   tihrddzPAqs            【5th Liveにて公開】 虹ヶ咲学園スクールアイドル同好会からのお知らせ🌈
# 2   0PeIh81yGZ4  【2022年9月16日配信】ラブライブ！スーパースター!! Liella!生放送～今夜はみん...
# 3   Jy6GgLCV8bk  ラブライブ！虹ヶ咲学園スクールアイドル同好会生放送 with You!! 5th Live!...
# 4   a4HGK2UFJGg              【やっぱりぶっつけ本番】Liella!のグッズ紹介 ～絵森彩のリベンジ編～
# 5   aaxj6XU-Akw  【第81回】ラブライブ！スーパースター!! 結女放課後放送局 リエラジ！／#81 Lovel...
# 6   Gs9YpmlIAvI  『きょうのAqours』第7回 桜内梨子　『Today&#39;s Aqours』 #7 R...
# 7   5BmbXBhgZzs                スクスタ イベントエピソード人気投票 第1位「モンスターハロウィン！」
# 8   pRkFI_Y2opI  【試聴動画】Liella!のドコいく？2nd Season Part.1（TVアニメ「ラブラ...
# 9   0PCpp8HOSNU  【SPOT】TVアニメ『ラブライブ！スーパースター!!』２期第６話挿入歌/第８話挿入歌「ビタ...
# 10  iTWUqL0P42Q  【試聴動画】TVアニメ『ラブライブ！スーパースター!!』２期第６話挿入歌/第８話挿入歌「ビタ...
# 11  4wKBNVE_DVU  【限定公開】Chance Day, Chance Way！ / Liella!【TVアニメ『...
# 12  N-VSgWHBxkw        【9/14(水)発売！】ラブライブ！シリーズ カウントダウンライブBD #Shorts
# ...

# %%
df.to_csv(r'C:\Users\squid\Data science lesson\Portforlio project\LLofficialDatab40920.CSV')
